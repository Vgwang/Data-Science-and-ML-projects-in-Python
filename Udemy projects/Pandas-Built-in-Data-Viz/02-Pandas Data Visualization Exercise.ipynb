# %% [markdown]
# # Pandas Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ** Create a scatterplot of b vs. a**

# %%
df3.plot.scatter(x='a', y='b', color = "red", s = 50, figsize = (12,3))
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# ** Create a histogram of the 'a' column.**

# %%
df3['a'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(bins = 35)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ** Create a boxplot comparing the a and b columns.**

# %%
df3[['a', 'b']].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ** Create a kde plot of the 'd' column **

# %%
df3['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ** Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
df3['d'].plot.kde(lw = 5, ls = '--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ** Create an area plot of all the columns for just the rows up to 30. (hint: use .iloc).**

# %%
df3.plot.area()
# Out:
# <AxesSubplot:>

# %%
df3.iloc[0:30].plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Figure out how to display the legend outside of the plot**

# %%
f = plt.figure()
df3.iloc[0:30].plot.area(alpha=0.4,ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
